# %% [markdown]
# # **Data Collection and Preparation - Weather Data**

# %%
import pandas as pd
import numpy as np

# %%
try:
    df = pd.read_csv('resources/csv_files/weather_burbank_airport.csv')
    print("Successfully imported weather_burbank_airport.csv")
except FileNotFoundError:
    print("Error: weather_burbank_airport.csv not found.")
# Out:
# Successfully imported weather_burbank_airport.csv

# %% [markdown]
# ## Format

# %%
df
# Out:
#           city            timestamp  temperature  cloud_cover  \
# 0      Burbank  2018-01-01 08:53:00          9.0         33.0
# 1      Burbank  2018-01-01 09:53:00          9.0         33.0
# 2      Burbank  2018-01-01 10:53:00          9.0         21.0
# 3      Burbank  2018-01-01 11:53:00          9.0         29.0
# 4      Burbank  2018-01-01 12:53:00          8.0         33.0
# ...        ...                  ...          ...          ...
# 29239  Burbank  2021-01-01 03:53:00         13.0         33.0
# 29240  Burbank  2021-01-01 04:53:00         12.0         33.0
# 29241  Burbank  2021-01-01 05:53:00         12.0         33.0
# 29242  Burbank  2021-01-01 06:53:00         11.0         33.0
# 29243  Burbank  2021-01-01 07:53:00         10.0         33.0
#
#       cloud_cover_description  pressure  windspeed  precipitation  \
# 0                        Fair    991.75        9.0            0.0
# 1                        Fair    992.08        0.0            0.0
# 2                        Haze    992.08        0.0            0.0
# 3               Partly Cloudy    992.08        0.0            0.0
# 4                        Fair    992.08        0.0            0.0
# ...                       ...       ...        ...            ...
# 29239                    Fair    986.81        0.0            0.0
# 29240                    Fair    986.81       11.0            0.0
# 29241                    Fair    987.47        9.0            0.0
# 29242                    Fair    987.14       13.0            0.0
# 29243                    Fair    987.80        6.0            0.0
#
#        felt_temperature
# 0                   8.0
# 1                   9.0
# 2                   9.0
# 3                   9.0
# 4                   8.0
# ...                 ...
# 29239              13.0
# 29240              12.0
# 29241              12.0
# 29242              11.0
# 29243              10.0
#
# [29244 rows x 9 columns]

# %% [markdown]
# Again, just as in the charging sessions, we will convert the values of **timestamp** from type object to datetime. Similar to as before, we know by the supplemented document of the team assignment that all datetimes are in UTC. For easier use, we will convert all datetimes from Timezone *UTC* to *America/Los Angeles*.

# %%
df['timestamp'] = pd.to_datetime(df['timestamp'], utc=True, errors='coerce').dt.tz_convert('America/Los_Angeles')

# %% [markdown]
# Again, let's a look at the number of unique values for each column.

# %%
df.nunique(dropna=True)
# Out:
# city                           1
# timestamp                  29244
# temperature                   45
# cloud_cover                   17
# cloud_cover_description       23
# pressure                      88
# windspeed                     28
# precipitation                 44
# felt_temperature              43
# dtype: int64

# %% [markdown]
# We see that there is only one unique value for *city* (as we would expect from a weather station), so we can drop that column.

# %%
df = df.drop(columns='city', axis=1)

# %% [markdown]
# ## Duplicates & Missing Data

# %% [markdown]
# Again, we check for duplicates:

# %%
len(df[df.duplicated()])
# Out:
# 0

# %% [markdown]
# Apparently there are none. We continue with checking if there are missing values:

# %%
df.isnull().sum()
# Out:
# timestamp                   0
# temperature                25
# cloud_cover                20
# cloud_cover_description    20
# pressure                    8
# windspeed                  86
# precipitation               0
# felt_temperature           26
# dtype: int64

# %% [markdown]
# There are some null values. Since we don't expect the weather to change much in an hour, we will use backfill.

# %%
df = df.bfill()

# %% [markdown]
# ## Transformation

# %% [markdown]
# Let's recall the values of our columns again:

# %%
df.cloud_cover_description.unique()
# Out:
# array(['Fair', 'Haze', 'Partly Cloudy', 'Mostly Cloudy', 'Cloudy', 'Fog',
#        'Light Rain', 'Rain', 'Heavy Rain', 'Heavy Rain / Windy',
#        'Light Rain / Windy', 'T-Storm', 'Fair / Windy', 'Cloudy / Windy',
#        'Mostly Cloudy / Windy', 'Partly Cloudy / Windy',
#        'Thunder in the Vicinity', 'Thunder', 'Smoke',
#        'Light Rain with Thunder', 'Heavy T-Storm', 'Rain / Windy',
#        'Blowing Dust'], dtype=object)

# %% [markdown]
# We realize that *cloud_cover_description* is a categorical value. Let's see how it relates to the *cloud_cover*.

# %%
for description in df.sort_values(by='cloud_cover').cloud_cover_description.unique():
    print(description, df[df.cloud_cover_description == description]['cloud_cover'].unique())
# Out:
# T-Storm [4.]
# Heavy T-Storm [4.]
# Light Rain with Thunder [4.]
# Light Rain [11.]
# Light Rain / Windy [11.]
# Rain [12.]
# Rain / Windy [12.]
# Blowing Dust [19.]
# Fog [20.]
# Haze [21.]
# Smoke [22.]
# Cloudy [26.]
# Cloudy / Windy [26.]
# Mostly Cloudy [28. 27.]
# Mostly Cloudy / Windy [28. 27.]
# Partly Cloudy [29. 30.]
# Partly Cloudy / Windy [30. 29.]
# Fair [33. 34.]
# Fair / Windy [34. 33.]
# Thunder in the Vicinity [38. 47.]
# Thunder [38.]
# Heavy Rain [40.]
# Heavy Rain / Windy [40.]

# %% [markdown]
# | **cloud_cover_description**| **cloud_cover**            |
# |----------------------------|-----------------------------|
# | T-Storm                    | `[4]`                      |
# | Heavy T-Storm              | `[4]`                      |
# | Light Rain with Thunder    | `[4]`                      |
# | Light Rain                 | `[11]`                     |
# | Light Rain / Windy         | `[11]`                     |
# | Rain                       | `[12]`                     |
# | Rain / Windy               | `[12]`                     |
# | Blowing Dust               | `[19]`                     |
# | Fog                        | `[20]`                     |
# | Haze                       | `[21]`                     |
# | Smoke                      | `[22]`                     |
# | Cloudy                     | `[26]`                     |
# | Cloudy / Windy             | `[26]`                     |
# | Mostly Cloudy              | `[28, 27]`                 |
# | Mostly Cloudy / Windy      | `[28, 27]`                 |
# | Partly Cloudy              | `[29, 30]`                 |
# | Partly Cloudy / Windy      | `[29, 30]`                 |
# | Fair                       | `[33, 34]`                 |
# | Fair / Windy               | `[33, 34]`                 |
# | Thunder in the Vicinity    | `[38, 47]`                 |
# | Thunder                    | `[38]`                     |
# | Heavy Rain                 | `[40]`                     |
# | Heavy Rain / Windy         | `[40]`                     |

# %% [markdown]
# We notice something very interesting: The *cloud_cover* seems to be categorical as well and each description can be mapped to a discrete *cloud_cover* value. There doesn't seem to be an order of the values (Cloudy has a cloud_cover of 26, while Partly Cloudy has a cloud_cover of [29, 30] and T-Storm (Thunderstorm) a value of 4.) Furthermore, if we look at the actual values, the name *cloud_cover_description* doesn't really fit to the data in the column (values like *Light Rain* or *Haze* are not a description of the clouds, but rather of the general weather conditions). Because of this, we have decided to use another weather dataset. We found the website *https://www.wunderground.com/weather/us/ca/burbank* from which we can extract historical weather data for the same weather station in Burbank. More importantly, we can retrieve the cloud cover in a scale according to [METAR](https://en.wikipedia.org/wiki/METAR), which we expect to be more suitable for our further analysis. The python script for scraping the data via the REST API can be found here [fetch-weather-data.py](../utils/fetch-weather-data.py).

# %%
try:
    new_df = pd.read_csv('resources/csv_files/new_burbank_weather_data.csv')
    print("Successfully imported burbank_weather_data.csv")
except FileNotFoundError:
    print("Error: burbank_weather_data.csv not found.")
# Out:
# Successfully imported burbank_weather_data.csv

# %%
new_df
# Out:
#                  timestamp  temperature clouds      wx_phrase  pressure  \
# 0      2018-01-01 08:53:00          9.0    CLR           Fair    991.75
# 1      2018-01-01 09:53:00          9.0    CLR           Fair    992.08
# 2      2018-01-01 10:53:00          9.0    CLR           Haze    992.08
# 3      2018-01-01 11:53:00          9.0    CLR  Partly Cloudy    992.08
# 4      2018-01-01 12:53:00          8.0    CLR           Fair    992.08
# ...                    ...          ...    ...            ...       ...
# 37226  2021-11-01 02:53:00         16.0    CLR           Fair    987.47
# 37227  2021-11-01 03:53:00         15.0    CLR           Fair    988.45
# 37228  2021-11-01 04:53:00         15.0    CLR           Haze    988.78
# 37229  2021-11-01 05:53:00         14.0    CLR           Fair    989.11
# 37230  2021-11-01 06:53:00         14.0    CLR           Haze    989.11
#
#        windspeed  precipitation  felt_temperature
# 0            9.0            0.0               8.0
# 1            0.0            0.0               9.0
# 2            0.0            0.0               9.0
# 3            0.0            0.0               9.0
# 4            0.0            0.0               8.0
# ...          ...            ...               ...
# 37226        9.0            0.0              16.0
# 37227        7.0            0.0              15.0
# 37228        7.0            0.0              15.0
# 37229        6.0            0.0              14.0
# 37230        0.0            0.0              14.0
#
# [37231 rows x 8 columns]

# %% [markdown]
# Again, we will handle the data as before.

# %%
new_df['timestamp'] = pd.to_datetime(new_df['timestamp'], utc=True, errors='coerce').dt.tz_convert('America/Los_Angeles')

# %%
new_df.nunique(dropna=True)
# Out:
# timestamp           37231
# temperature            45
# clouds                  5
# wx_phrase              24
# pressure               88
# windspeed              28
# precipitation          46
# felt_temperature       43
# dtype: int64

# %%
len(new_df[new_df.duplicated()])
# Out:
# 0

# %%
new_df.isnull().sum()
# Out:
# timestamp             0
# temperature          29
# clouds               51
# wx_phrase            33
# pressure             18
# windspeed           130
# precipitation         0
# felt_temperature     31
# dtype: int64

# %%
new_df = new_df.bfill()

# %% [markdown]
# Because we still have the categorical features *clouds* and *wx_phrase*, we are going to transform them.
# For that, we will look at their values again:

# %%
new_df.clouds.unique()
# Out:
# array(['CLR', 'OVC', 'SCT', 'FEW', 'BKN'], dtype=object)

# %% [markdown]
# We can define an ordering on the clouds via the METAR scale: CLR < FEW < SCT < BKN < OVC. This allows us to encode those numerically:

# %%
cloud_cover_map = {
    'CLR': 0,
    'FEW': 1,
    'SCT': 2,
    'BKN': 3,
    'OVC': 4
}
new_df.loc[:, 'clouds'] = new_df['clouds'].map(cloud_cover_map)
new_df[new_df.clouds != 0]
# Out:
#                       timestamp  temperature clouds      wx_phrase  pressure  \
# 65    2018-01-03 17:53:00-08:00         19.0      4         Cloudy    989.11
# 67    2018-01-03 19:53:00-08:00         18.0      2  Partly Cloudy    989.44
# 68    2018-01-03 20:53:00-08:00         17.0      1  Partly Cloudy    990.10
# 73    2018-01-04 01:53:00-08:00         12.0      1  Partly Cloudy    990.76
# 74    2018-01-04 02:53:00-08:00         12.0      4         Cloudy    991.09
# ...                         ...          ...    ...            ...       ...
# 37214 2021-10-31 10:53:00-07:00         16.0      4           Haze    988.78
# 37215 2021-10-31 11:53:00-07:00         16.0      4           Haze    988.45
# 37216 2021-10-31 12:00:00-07:00         16.0      4         Cloudy    988.45
# 37217 2021-10-31 12:53:00-07:00         17.0      4         Cloudy    987.80
# 37218 2021-10-31 13:38:00-07:00         18.0      2  Partly Cloudy    987.14
#
#        windspeed  precipitation  felt_temperature
# 65           0.0            0.0              19.0
# 67           0.0            0.0              18.0
# 68           0.0            0.0              17.0
# 73           0.0            0.0              12.0
# 74           6.0            0.0              12.0
# ...          ...            ...               ...
# 37214       11.0            0.0              16.0
# 37215        6.0            0.0              16.0
# 37216        6.0            0.0              16.0
# 37217        0.0            0.0              17.0
# 37218        7.0            0.0              18.0
#
# [11432 rows x 8 columns]

# %%
for description in new_df.loc[new_df['windspeed'].sort_values().index].wx_phrase.unique():
    print(description, "min:", new_df[new_df.wx_phrase == description]['windspeed'].min(), "max:", new_df[new_df.wx_phrase == description]['windspeed'].max())
# Out:
# Haze min: 0.0 max: 30.0
# Fair min: 0.0 max: 31.0
# Partly Cloudy min: 0.0 max: 31.0
# Fog min: 0.0 max: 19.0
# Cloudy min: 0.0 max: 31.0
# Mostly Cloudy min: 0.0 max: 31.0
# Light Rain min: 0.0 max: 31.0
# Rain min: 0.0 max: 31.0
# Smoke min: 0.0 max: 20.0
# T-Storm min: 0.0 max: 24.0
# Heavy Rain min: 0.0 max: 31.0
# Thunder in the Vicinity min: 0.0 max: 28.0
# Heavy T-Storm min: 7.0 max: 20.0
# Light Rain with Thunder min: 15.0 max: 24.0
# Blowing Dust min: 15.0 max: 28.0
# Thunder min: 15.0 max: 19.0
# Rain / Windy min: 33.0 max: 44.0
# Light Rain / Windy min: 33.0 max: 37.0
# Fair / Windy min: 33.0 max: 52.0
# Mostly Cloudy / Windy min: 33.0 max: 57.0
# Partly Cloudy / Windy min: 33.0 max: 44.0
# Cloudy / Windy min: 33.0 max: 48.0
# Haze / Windy min: 35.0 max: 43.0
# Heavy Rain / Windy min: 37.0 max: 46.0

# %% [markdown]
# We see that there is a clear distinction between Descriptions with and without the word *Windy*. As soon as the windspeed is above 33, it is considered as windy. Now to lower the overall dimensionality, we want to add a new feature called *Windy*. Doing so, we can summarize the records *Partly Cloudy* with *Partly Cloudy / Windy*, *Fair* with *Fair / Windy* and so on.

# %%
new_df['windy'] = np.where(new_df['wx_phrase'].str.contains("Windy"), 1, 0)
new_df.loc[:,'wx_phrase'] = new_df.loc[:, 'wx_phrase'].str.replace(' / Windy', '', regex=True)
new_df[new_df.windy == 1]
# Out:
#                       timestamp  temperature clouds      wx_phrase  pressure  \
# 215   2018-01-09 04:43:00-08:00         14.0      4     Heavy Rain    975.28
# 216   2018-01-09 04:53:00-08:00         14.0      4     Light Rain    974.95
# 217   2018-01-09 05:02:00-08:00         14.0      4     Light Rain    974.63
# 218   2018-01-09 05:16:00-08:00         14.0      4     Light Rain    974.63
# 219   2018-01-09 05:53:00-08:00         13.0      4     Heavy Rain    975.61
# ...                         ...          ...    ...            ...       ...
# 36664 2021-10-11 16:53:00-07:00         21.0      3  Mostly Cloudy    974.95
# 36665 2021-10-11 17:21:00-07:00         19.0      3           Haze    975.28
# 36666 2021-10-11 17:53:00-07:00         19.0      4           Haze    975.61
# 36672 2021-10-11 21:53:00-07:00         17.0      0           Fair    979.56
# 36677 2021-10-12 02:53:00-07:00         15.0      0           Fair    980.88
#
#        windspeed  precipitation  felt_temperature  windy
# 215         37.0           3.05              14.0      1
# 216         33.0           3.30              14.0      1
# 217         33.0           0.00              14.0      1
# 218         37.0           0.00              14.0      1
# 219         43.0           3.81              13.0      1
# ...          ...            ...               ...    ...
# 36664       35.0           0.00              21.0      1
# 36665       35.0           0.00              19.0      1
# 36666       43.0           0.00              19.0      1
# 36672       44.0           0.00              17.0      1
# 36677       35.0           0.00              15.0      1
#
# [166 rows x 9 columns]

# %% [markdown]
# For easier use, let us aggregate the weather data by the hour

# %%
new_df['hour'] = new_df['timestamp'].dt.floor('h', ambiguous='infer')
hourly_aggregated_df = new_df.groupby('hour').agg({
    'temperature': 'mean',
    'clouds': lambda x: x.mode()[0],
    'wx_phrase': lambda x: x.mode()[0],
    'pressure': 'mean',
    'windspeed': 'mean',
    'precipitation': 'sum',
    'felt_temperature': 'mean',
    'windy': lambda x: x.mode()[0]
}).reset_index()
hourly_aggregated_df
# Out:
#                            hour  temperature  clouds      wx_phrase  pressure  \
# 0     2018-01-01 00:00:00-08:00          9.0       0           Fair    991.75
# 1     2018-01-01 01:00:00-08:00          9.0       0           Fair    992.08
# 2     2018-01-01 02:00:00-08:00          9.0       0           Haze    992.08
# 3     2018-01-01 03:00:00-08:00          9.0       0  Partly Cloudy    992.08
# 4     2018-01-01 04:00:00-08:00          8.0       0           Fair    992.08
# ...                         ...          ...     ...            ...       ...
# 33464 2021-10-31 19:00:00-07:00         16.0       0           Fair    987.47
# 33465 2021-10-31 20:00:00-07:00         15.0       0           Fair    988.45
# 33466 2021-10-31 21:00:00-07:00         15.0       0           Haze    988.78
# 33467 2021-10-31 22:00:00-07:00         14.0       0           Fair    989.11
# 33468 2021-10-31 23:00:00-07:00         14.0       0           Haze    989.11
#
#        windspeed  precipitation  felt_temperature  windy
# 0            9.0            0.0               8.0      0
# 1            0.0            0.0               9.0      0
# 2            0.0            0.0               9.0      0
# 3            0.0            0.0               9.0      0
# 4            0.0            0.0               8.0      0
# ...          ...            ...               ...    ...
# 33464        9.0            0.0              16.0      0
# 33465        7.0            0.0              15.0      0
# 33466        7.0            0.0              15.0      0
# 33467        6.0            0.0              14.0      0
# 33468        0.0            0.0              14.0      0
#
# [33469 rows x 9 columns]

# %% [markdown]
# For later use in our machine learning algorithms, we will transform the categorical values of wx_phrase to dummy variables.

# %%
hourly_aggregated_df = pd.get_dummies(hourly_aggregated_df, columns=["wx_phrase"])
hourly_aggregated_df
# Out:
#                            hour  temperature  clouds  pressure  windspeed  \
# 0     2018-01-01 00:00:00-08:00          9.0       0    991.75        9.0
# 1     2018-01-01 01:00:00-08:00          9.0       0    992.08        0.0
# 2     2018-01-01 02:00:00-08:00          9.0       0    992.08        0.0
# 3     2018-01-01 03:00:00-08:00          9.0       0    992.08        0.0
# 4     2018-01-01 04:00:00-08:00          8.0       0    992.08        0.0
# ...                         ...          ...     ...       ...        ...
# 33464 2021-10-31 19:00:00-07:00         16.0       0    987.47        9.0
# 33465 2021-10-31 20:00:00-07:00         15.0       0    988.45        7.0
# 33466 2021-10-31 21:00:00-07:00         15.0       0    988.78        7.0
# 33467 2021-10-31 22:00:00-07:00         14.0       0    989.11        6.0
# 33468 2021-10-31 23:00:00-07:00         14.0       0    989.11        0.0
#
#        precipitation  felt_temperature  windy  wx_phrase_Blowing Dust  \
# 0                0.0               8.0      0                   False
# 1                0.0               9.0      0                   False
# 2                0.0               9.0      0                   False
# 3                0.0               9.0      0                   False
# 4                0.0               8.0      0                   False
# ...              ...               ...    ...                     ...
# 33464            0.0              16.0      0                   False
# 33465            0.0              15.0      0                   False
# 33466            0.0              15.0      0                   False
# 33467            0.0              14.0      0                   False
# 33468            0.0              14.0      0                   False
#
#        wx_phrase_Cloudy  ...  wx_phrase_Haze  wx_phrase_Heavy Rain  \
# 0                 False  ...           False                 False
# 1                 False  ...           False                 False
# 2                 False  ...            True                 False
# 3                 False  ...           False                 False
# 4                 False  ...           False                 False
# ...                 ...  ...             ...                   ...
# 33464             False  ...           False                 False
# 33465             False  ...           False                 False
# 33466             False  ...            True                 False
# 33467             False  ...           False                 False
# 33468             False  ...            True                 False
#
#        wx_phrase_Heavy T-Storm  wx_phrase_Light Rain  wx_phrase_Mostly Cloudy  \
# 0                        False                 False                    False
# 1                        False                 False                    False
# 2                        False                 False                    False
# 3                        False                 False                    False
# 4                        False                 False                    False
# ...                        ...                   ...                      ...
# 33464                    False                 False                    False
# 33465                    False                 False                    False
# 33466                    False                 False                    False
# 33467                    False                 False                    False
# 33468                    False                 False                    False
#
#        wx_phrase_Partly Cloudy  wx_phrase_Rain  wx_phrase_Smoke  \
# 0                        False           False            False
# 1                        False           False            False
# 2                        False           False            False
# 3                         True           False            False
# 4                        False           False            False
# ...                        ...             ...              ...
# 33464                    False           False            False
# 33465                    False           False            False
# 33466                    False           False            False
# 33467                    False           False            False
# 33468                    False           False            False
#
#        wx_phrase_T-Storm  wx_phrase_Thunder in the Vicinity
# 0                  False                              False
# 1                  False                              False
# 2                  False                              False
# 3                  False                              False
# 4                  False                              False
# ...                  ...                                ...
# 33464              False                              False
# 33465              False                              False
# 33466              False                              False
# 33467              False                              False
# 33468              False                              False
#
# [33469 rows x 22 columns]

# %%
hourly_aggregated_df.to_csv('resources/csv_files/new_burbank_weather_data_prepared.csv', index=False)
hourly_aggregated_df.to_pickle('resources/pickle_files/new_burbank_weather_data_prepared.pkl')
